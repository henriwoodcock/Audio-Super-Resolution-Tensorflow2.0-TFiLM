# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# %cp -r "drive/My Drive/audio-super-res/" .

# %%
# !mv audio-super-res/* .

# %%
# !ls
# Out:
# audio-super-res  Dockerfile  model	       sample_data  utils.py
# data		 drive	     README.md	       test.py
# dataset.py	 h5_data.py  requirements.txt  train.py

# %%
# !cd data && unzip 1_person_VCTK_dataset.zip
# Out:
# Archive:  1_person_VCTK_dataset.zip
#    creating: test_hr/
#   inflating: test_hr/p225_355.wav
#   inflating: test_hr/p225_356.wav
#   inflating: test_hr/p225_357.wav
#   inflating: test_hr/p225_358.wav
#   inflating: test_hr/p225_359.wav
#   inflating: test_hr/p225_363.wav
#   inflating: test_hr/p225_365.wav
#   inflating: test_hr/p225_366.wav
#    creating: test_lr/
#   inflating: test_lr/p225_355.wav
#   inflating: test_lr/p225_356.wav
#   inflating: test_lr/p225_357.wav
#   inflating: test_lr/p225_358.wav
#   inflating: test_lr/p225_359.wav
#   inflating: test_lr/p225_363.wav
#   inflating: test_lr/p225_365.wav
#   inflating: test_lr/p225_366.wav
#    creating: train_hr/
#   inflating: train_hr/p225_001.wav
#   inflating: train_hr/p225_002.wav
#   inflating: train_hr/p225_003.wav
#   inflating: train_hr/p225_004.wav
#   inflating: train_hr/p225_005.wav
#   inflating: train_hr/p225_006.wav
#   inflating: train_hr/p225_007.wav
#   inflating: train_hr/p225_008.wav
# ...

# %%
# !ls
# Out:
# audio-super-res  Dockerfile  model	       sample_data  utils.py
# data		 drive	     README.md	       test.py
# dataset.py	 h5_data.py  requirements.txt  train.py

# %%
# !python h5_data.py
# Out:
# Creating training dataset...
# 100% 223/223 [00:03<00:00, 64.11it/s]
#
# Creating testing dataset...
# 100% 8/8 [00:00<00:00, 75.29it/s]

# %%
# !python train.py
# Out:
# 2021-03-05 09:50:25.730190: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-05 09:50:28.439575: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-05 09:50:28.440704: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-05 09:50:28.476711: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-03-05 09:50:28.476809: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: 693077d21a41
# 2021-03-05 09:50:28.476833: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: 693077d21a41
# 2021-03-05 09:50:28.477096: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 460.32.3
# ...
